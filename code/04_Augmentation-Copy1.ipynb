# %% [markdown]
# # Augmentation

# %% [markdown]
# Augmentation for MRI has its limitaions. The model needs to recognize a specific pattern or shape that is common for each class and it can be disturbed by the augmentation. I will fit the models using augmented images from ImageDataGenerator and Albumentations. Ideas for augmentation types from https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5977656/

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import layers
from tensorflow import cast, image, numpy_function
from tensorflow.keras.applications import EfficientNetV2S, resnet50
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import resnet50
from tensorflow.image import grayscale_to_rgb
from tensorflow import convert_to_tensor
from tensorflow.keras.utils import to_categorical, load_img, img_to_array
from tensorflow import expand_dims

import albumentations as A
import cv2
from os import listdir
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

import functions

import numpy as np
np.random.seed(18)

# %%
# Set image size
image_size = 240

# Set Early stopping
es = EarlyStopping(patience = 5, restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0001)

# Path to Alzheimer's data
al_path_train = '../data/alzheimer/train'
al_path_test = '../data/alzheimer/test'

# Path to Brain Tumor data
bt_path_train = '../data/brain_tumor/train'
bt_path_test = '../data/brain_tumor/test'

# %%
# ImageDataGenerator
datagen = ImageDataGenerator(
        zoom_range=0.1,        
        width_shift_range=0.05,
        height_shift_range=0.05, 
        horizontal_flip=True,
        validation_split=0.20)

# %%
al_train_dg = datagen.flow_from_directory(
                  directory=al_path_train,
                  target_size=(image_size, image_size), # resize to this size
                  batch_size=1, # number of images to extract from folder for every batch
                  class_mode="categorical", # classes to predict
                  seed=18 # to make the result reproducible
                  )

al_val_dg = datagen.flow_from_directory(
                  directory=al_path_train,
                  target_size=(image_size, image_size), # resize to this size
                  batch_size=1, # number of images to extract from folder for every batch
                  class_mode="categorical", # classes to predict
                  seed=18,
                  shuffle=True,
                  subset='validation'
                  )


fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(15,15))

for i in range(4):
    # convert to unsigned integers for plotting
    image = next(al_train_dg)[0].astype('uint8')

    # changing size for plotting the image
    image = np.squeeze(image)

    # plot raw pixel data
    ax[i].imshow(image)
    ax[i].axis('off')
# Out:
# Found 5121 images belonging to 4 classes.
# Found 1023 images belonging to 4 classes.

# %%
es = EarlyStopping(patience = 5)

model = Sequential()


model.add(layers.Input(shape=(image_size, image_size, 1)))
model.add(layers.Rescaling(1./255))

#First Convolution
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#Second Convolution
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
#Flatten
model.add(Flatten())
# Fully Connected
model.add(Dense(32, activation = 'relu'))
model.add(Dense(4, activation='softmax'))

# Compile
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

h = model.fit(al_train_dg, validation_data = al_val_dg, steps_per_epoch=len(al_train_dg) / 32, epochs=50, callbacks = [es])
# Out:
# Epoch 1/50
# 160/160 [==============================] - 15s 88ms/step - loss: 1.4372 - accuracy: 0.4472 - val_loss: 1.2433 - val_accuracy: 0.5005
# Epoch 2/50
# 160/160 [==============================] - 13s 83ms/step - loss: 1.1464 - accuracy: 0.4037 - val_loss: 1.0429 - val_accuracy: 0.5005
# Epoch 3/50
# 160/160 [==============================] - 13s 83ms/step - loss: 1.0644 - accuracy: 0.5280 - val_loss: 1.0590 - val_accuracy: 0.5005
# Epoch 4/50
# 160/160 [==============================] - 14s 87ms/step - loss: 1.1192 - accuracy: 0.4969 - val_loss: 1.1659 - val_accuracy: 0.3500
# Epoch 5/50
# 160/160 [==============================] - 13s 80ms/step - loss: 1.0524 - accuracy: 0.4596 - val_loss: 1.0411 - val_accuracy: 0.5005
# Epoch 6/50
# 160/160 [==============================] - 13s 84ms/step - loss: 0.9918 - accuracy: 0.5280 - val_loss: 1.0414 - val_accuracy: 0.5005
# Epoch 7/50
# 160/160 [==============================] - 13s 81ms/step - loss: 1.0362 - accuracy: 0.4783 - val_loss: 1.0372 - val_accuracy: 0.5005
# Epoch 8/50
# 160/160 [==============================] - 13s 84ms/step - loss: 1.0392 - accuracy: 0.4907 - val_loss: 1.0362 - val_accuracy: 0.5005
# Epoch 9/50
# 160/160 [==============================] - 14s 87ms/step - loss: 1.0110 - accuracy: 0.5652 - val_loss: 1.0486 - val_accuracy: 0.5005
# Epoch 10/50
# 160/160 [==============================] - 13s 84ms/step - loss: 1.1519 - accuracy: 0.4720 - val_loss: 1.1120 - val_accuracy: 0.5005
# Epoch 11/50
# 160/160 [==============================] - 13s 84ms/step - loss: 1.0959 - accuracy: 0.4658 - val_loss: 1.0375 - val_accuracy: 0.5005
# Epoch 12/50
# 160/160 [==============================] - 13s 83ms/step - loss: 1.1163 - accuracy: 0.4161 - val_loss: 1.0416 - val_accuracy: 0.5005
# Epoch 13/50
# 160/160 [==============================] - 13s 82ms/step - loss: 1.0469 - accuracy: 0.5404 - val_loss: 1.0409 - val_accuracy: 0.5005

# %% [markdown]
# The model fails to learn anything from augmented data.

# %% [markdown]
# # Brain Tumor

# %%
bt_train_dg = datagen.flow_from_directory(
                  directory=bt_path_train,
                  target_size=(image_size, image_size), # resize to this size
                  batch_size=1, # number of images to extract from folder for every batch
                  class_mode="categorical", # classes to predict
                  seed=18,
                  shuffle=True,
                  subset='training'
                  )

bt_val_dg = datagen.flow_from_directory(
                  directory=bt_path_train,
                  target_size=(image_size, image_size), # resize to this size
                  batch_size=1, # number of images to extract from folder for every batch
                  class_mode="categorical", # classes to predict
                  seed=18,
                  shuffle=True,
                  subset='validation'
                  )

fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(15,15))

for i in range(4):
    # convert to unsigned integers for plotting
    image = next(bt_train_dg)[0].astype('uint8')

    # changing size for plotting the image
    image = np.squeeze(image)

    # plot raw pixel data
    ax[i].imshow(image, cmap='gray')
    ax[i].axis('off')
# Out:
# Found 2297 images belonging to 4 classes.
# Found 573 images belonging to 4 classes.

# %%
effnet = EfficientNetV2S(
    include_top=False,
    weights="imagenet",
    input_shape=(image_size, image_size, 3),
    classes=4,
    classifier_activation="softmax",
    include_preprocessing=True,
)

# Freeze last 5 layers
for layer in effnet.layers[:-5]:
    layer.trainable = False

    
model = Sequential()
model.add(layers.Rescaling(1./255))

model.add(effnet)
model.add(GlobalAveragePooling2D())
model.add(Dropout(.2))

#Just use a single output layer
model.add(Dense(4, activation='softmax'))

# Compile
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])    

h = model.fit(bt_train_dg, validation_data = bt_val_dg, steps_per_epoch=len(bt_train_dg) / 32, epochs=30, callbacks = [es, reduce_lr])
# Out:
# Epoch 1/30
# 71/71 [==============================] - 215s 3s/step - loss: 1.3652 - accuracy: 0.3889 - val_loss: 1.3084 - val_accuracy: 0.3141 - lr: 0.0010
# Epoch 2/30
# 71/71 [==============================] - 189s 3s/step - loss: 1.3256 - accuracy: 0.3611 - val_loss: 1.2363 - val_accuracy: 0.3194 - lr: 0.0010
# Epoch 3/30
# 71/71 [==============================] - 146s 2s/step - loss: 1.3173 - accuracy: 0.3056 - val_loss: 1.1463 - val_accuracy: 0.4363 - lr: 0.0010
# Epoch 4/30
# 71/71 [==============================] - 76s 1s/step - loss: 1.2340 - accuracy: 0.4444 - val_loss: 1.1493 - val_accuracy: 0.4677 - lr: 0.0010
# Epoch 5/30
# 71/71 [==============================] - 124s 2s/step - loss: 1.2525 - accuracy: 0.4722 - val_loss: 1.2015 - val_accuracy: 0.4433 - lr: 0.0010
# Epoch 6/30
# 71/71 [==============================] - 77s 1s/step - loss: 1.2068 - accuracy: 0.4306 - val_loss: 1.1124 - val_accuracy: 0.5131 - lr: 0.0010
# Epoch 7/30
# 71/71 [==============================] - 121s 2s/step - loss: 1.2751 - accuracy: 0.3889 - val_loss: 1.2256 - val_accuracy: 0.4538 - lr: 0.0010
# Epoch 8/30
# 71/71 [==============================] - 222s 3s/step - loss: 1.0981 - accuracy: 0.4861 - val_loss: 1.4400 - val_accuracy: 0.4415 - lr: 0.0010
# Epoch 9/30
# 71/71 [==============================] - 281s 4s/step - loss: 0.9411 - accuracy: 0.6389 - val_loss: 1.4314 - val_accuracy: 0.4642 - lr: 0.0010
# Epoch 10/30
# 71/71 [==============================] - 295s 4s/step - loss: 1.2249 - accuracy: 0.3750 - val_loss: 1.4151 - val_accuracy: 0.4468 - lr: 0.0010
# Epoch 11/30
# 71/71 [==============================] - 294s 4s/step - loss: 1.0270 - accuracy: 0.5139 - val_loss: 1.6342 - val_accuracy: 0.4433 - lr: 0.0010

# %% [markdown]
# For Brain Tumors, augmentation works even worse than for Alzheimer's. I will try Albumentations and add the augmented images to the training set to increase the number of images to train on.

# %% [markdown]
# ## Albumentations

# %%
transform = A.Compose([
    A.HorizontalFlip(p=0.25),
    A.RandomBrightnessContrast(p=0.25),
    A.GaussNoise(p=0.5),
    #A.Rotate(limit=10, p=0.5),    
    #A.RandomScale(scale_limit=0.1, p=0.5)
])

# %%
def ald_augmentation(X_train, y_train):
    # Make a copy of the training set and augment it
    X_aug = []
    for image in X_train:
        image = transform(image=image)['image']
        image = cv2.resize(image, (image_size, image_size))
        X_aug.append(image)
    # Add augmented data to training set
    X_train = X_train + X_aug
    y_train = y_train + y_train
    # Prepare data for Tensorflow model
    X_train = np.array(X_train, dtype='float32')
    y_train = to_categorical(y_train, num_classes=4, dtype='float32')
    return X_train, y_train

# %%
def alb_prepare_data(path):
    X = []
    y = []

    for num_label, label in enumerate(listdir(path)):
            # Change each image and append to X and y
            for image in listdir(f'{path}/{label}'):
                if '.jpg' in image:
                    img = load_img(f'{path}/{label}/{image}', target_size=(image_size, image_size), color_mode='grayscale')
                    img = expand_dims(img, -1)
                    # Make image RGB for pre-trained models
                    img = grayscale_to_rgb(img)
                    img_arr = img_to_array(img) 

                    X.append(img_arr)
                    y.append(num_label)
                    
    if 'train' in path:     
            X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=18, stratify=y) 
                   
            X_val = np.array(X_val, dtype='float32')
            y_val = to_categorical(y_val, num_classes=4, dtype='float32')
            # Apply augmentation on trainig set 
            X_train, y_train = ald_augmentation(X_train, y_train)
            return X_train, X_val, y_train, y_val
    else:
            
            X_test = np.array(X, dtype='float32')
            y_test = to_categorical(y, num_classes=4, dtype='float32')
            return X_test, y_test

# %% [markdown]
# ### Alzheimer's

# %%
X_train, X_val, y_train, y_val = alb_prepare_data(al_path_train)
# Check the shape of the data
X_train.shape, y_train.shape
# Out:
# ((7680, 240, 240, 3), (7680, 4))

# %%
X_test, y_test = alb_prepare_data(al_path_test)

# %%
# This model gave better scores on non augmented data
rn_model = resnet50.ResNet50(
    include_top=False,
    weights="imagenet",
    input_shape=(image_size, image_size, 3),
    classes=4,
    classifier_activation="softmax"
)

# %%
# Freeze layers
for layer in rn_model.layers:
    layer.trainable = False

# %%
model = Sequential()

model.add(rn_model)
model.add(Flatten())

#Just use a single output layer
model.add(Dense(4, activation='softmax'))

# Compile
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

h_rn = model.fit(X_train, y_train, validation_data = (X_val, y_val), steps_per_epoch=len(X_train) / 32, epochs=30, callbacks = [es, reduce_lr])
# Out:
# Epoch 1/30
# 240/240 [==============================] - 1051s 4s/step - loss: 5.5893 - accuracy: 0.5603 - val_loss: 4.4787 - val_accuracy: 0.6097 - lr: 0.0010
# Epoch 2/30
# 240/240 [==============================] - 1049s 4s/step - loss: 2.2643 - accuracy: 0.6935 - val_loss: 1.2210 - val_accuracy: 0.8298 - lr: 0.0010
# Epoch 3/30
# 240/240 [==============================] - 1053s 4s/step - loss: 2.0294 - accuracy: 0.7471 - val_loss: 1.4373 - val_accuracy: 0.8470 - lr: 0.0010
# Epoch 4/30
# 240/240 [==============================] - 1053s 4s/step - loss: 1.5653 - accuracy: 0.7645 - val_loss: 1.0350 - val_accuracy: 0.8759 - lr: 0.0010
# Epoch 5/30
# 240/240 [==============================] - 1021s 4s/step - loss: 1.7360 - accuracy: 0.7822 - val_loss: 3.5226 - val_accuracy: 0.7806 - lr: 0.0010
# Epoch 6/30
# 240/240 [==============================] - 847s 4s/step - loss: 1.3188 - accuracy: 0.7949 - val_loss: 0.9571 - val_accuracy: 0.8938 - lr: 0.0010
# Epoch 7/30
# 240/240 [==============================] - 1020s 4s/step - loss: 1.8160 - accuracy: 0.7807 - val_loss: 1.4480 - val_accuracy: 0.8806 - lr: 0.0010
# Epoch 8/30
# 240/240 [==============================] - 1014s 4s/step - loss: 1.2298 - accuracy: 0.8177 - val_loss: 1.3852 - val_accuracy: 0.8720 - lr: 0.0010
# Epoch 9/30
# 240/240 [==============================] - 1014s 4s/step - loss: 1.0567 - accuracy: 0.8098 - val_loss: 1.1949 - val_accuracy: 0.8813 - lr: 0.0010
# Epoch 10/30
# 240/240 [==============================] - 941s 4s/step - loss: 1.1261 - accuracy: 0.8189 - val_loss: 3.4188 - val_accuracy: 0.7666 - lr: 0.0010
# Epoch 11/30
# 240/240 [==============================] - 671s 3s/step - loss: 0.9677 - accuracy: 0.8206 - val_loss: 2.2764 - val_accuracy: 0.8259 - lr: 0.0010

# %%
# Plot Crossentropy and Accuracy by epoch
functions.evaluation_plots(h_rn, 'Alzheimer\'s disease with Augmentation')

# %%
# Testing set Plot Confusion Matrix and print Accuracy
functions.acc_conf_matrix(model, X=X_val, y=y_val, class_names_list =  ['Mild', 'Moderate', 'No', 'Very Mild'])
# Out:
# Accuracy_score: 0.8938

# %%
# Testing set Plot Confusion Matrix and print Accuracy
functions.acc_conf_matrix(model, X=X_test, y=y_test, class_names_list =  ['Mild', 'Moderate', 'No', 'Very Mild'])
# Out:
# Accuracy_score: 0.6145

# %%
model = Sequential()

model.add(rn_model)
model.add(Flatten())

#Just use a single output layer
model.add(Dense(4, activation='softmax'))

# Compile
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

h_rn = model.fit(X_train, y_train, validation_data = (X_val, y_val), steps_per_epoch=len(X_train) / 32, epochs=30, callbacks = [es, reduce_lr])
# Out:
# Epoch 1/30
# 240/240 [==============================] - 571s 2s/step - loss: 4.7788 - accuracy: 0.5544 - val_loss: 4.2799 - val_accuracy: 0.5902 - lr: 0.0010
# Epoch 2/30
# 240/240 [==============================] - 547s 2s/step - loss: 2.4947 - accuracy: 0.6801 - val_loss: 2.1293 - val_accuracy: 0.7557 - lr: 0.0010
# Epoch 3/30
# 240/240 [==============================] - 531s 2s/step - loss: 2.0047 - accuracy: 0.7355 - val_loss: 1.0744 - val_accuracy: 0.8587 - lr: 0.0010
# Epoch 4/30
# 240/240 [==============================] - 539s 2s/step - loss: 1.2658 - accuracy: 0.7684 - val_loss: 2.5283 - val_accuracy: 0.7814 - lr: 0.0010
# Epoch 5/30
# 240/240 [==============================] - 543s 2s/step - loss: 1.5132 - accuracy: 0.7719 - val_loss: 1.9021 - val_accuracy: 0.8283 - lr: 0.0010
# Epoch 6/30
# 240/240 [==============================] - 537s 2s/step - loss: 1.6293 - accuracy: 0.7798 - val_loss: 1.0501 - val_accuracy: 0.8798 - lr: 0.0010
# Epoch 7/30
# 240/240 [==============================] - 523s 2s/step - loss: 1.5034 - accuracy: 0.7801 - val_loss: 2.1803 - val_accuracy: 0.8150 - lr: 0.0010
# Epoch 8/30
# 240/240 [==============================] - 449s 2s/step - loss: 1.4093 - accuracy: 0.7815 - val_loss: 2.0922 - val_accuracy: 0.8571 - lr: 0.0010
# Epoch 9/30
# 240/240 [==============================] - 345s 1s/step - loss: 1.6097 - accuracy: 0.7889 - val_loss: 1.8747 - val_accuracy: 0.8696 - lr: 0.0010
# Epoch 10/30
# 240/240 [==============================] - 338s 1s/step - loss: 1.5199 - accuracy: 0.7980 - val_loss: 1.3892 - val_accuracy: 0.8845 - lr: 0.0010
# Epoch 11/30
# 240/240 [==============================] - 327s 1s/step - loss: 1.2431 - accuracy: 0.8120 - val_loss: 6.5689 - val_accuracy: 0.7268 - lr: 0.0010

# %%
# Plot Crossentropy and Accuracy by epoch
functions.evaluation_plots(h_rn, 'Alzheimer\'s disease with Augmentation')

# %%
# Testing set Plot Confusion Matrix and print Accuracy
functions.acc_conf_matrix(model, X=X_val, y=y_val, class_names_list =  ['Mild', 'Moderate', 'No', 'Very Mild'])
# Out:
# Accuracy_score: 0.8798

# %%
# Testing set Plot Confusion Matrix and print Accuracy
functions.acc_conf_matrix(model, X=X_test, y=y_test, class_names_list =  ['Mild', 'Moderate', 'No', 'Very Mild'])
# Out:
# Accuracy_score: 0.6646

# %% [markdown]
# Augmentation did not improve the accuracy of the model. Without Augmentation accuracy was 0.67

# %% [markdown]
# ### Brain Tumor

# %%
transform = A.Compose([
    A.HorizontalFlip(p=0.25),
    #A.RandomBrightnessContrast(p=0.5),
    A.GaussNoise(p=0.5),
    A.Rotate(limit=10, p=0.5),    
    A.RandomScale(scale_limit=0.1, p=0.25)
])

# %%
X_train, X_val, y_train, y_val = alb_prepare_data(bt_path_train)
X_train.shape, y_train.shape
# Out:
# ((4304, 240, 240, 3), (4304, 4))

# %%
X_test, y_test = alb_prepare_data(bt_path_test)

# %%
effnet = EfficientNetV2S(
    include_top=False,
    weights="imagenet",
    input_shape=(image_size, image_size, 3),
    classes=4,
    classifier_activation="softmax",
    include_preprocessing=True,
)
# Freeze last 5 layers
for layer in effnet.layers[:-5]:
    layer.trainable = False

# %%
model = Sequential()

model.add(effnet)
model.add(GlobalAveragePooling2D())
model.add(Dropout(.2))

#Just use a single output layer
model.add(Dense(4, activation='softmax'))

# Compile
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

h_efv2s = model.fit(X_train, y_train, validation_data = (X_val, y_val), steps_per_epoch=len(X_train) / 32, epochs=30, callbacks = [es, reduce_lr])
# Out:
# Epoch 1/30
# 134/134 [==============================] - 938s 6s/step - loss: 0.7461 - accuracy: 0.6808 - val_loss: 0.3175 - val_accuracy: 0.8747 - lr: 0.0010
# Epoch 2/30
# 134/134 [==============================] - 870s 6s/step - loss: 0.5623 - accuracy: 0.7628 - val_loss: 0.2741 - val_accuracy: 0.9067 - lr: 0.0010
# Epoch 3/30
# 134/134 [==============================] - 871s 6s/step - loss: 0.5093 - accuracy: 0.7790 - val_loss: 0.3326 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 4/30
# 134/134 [==============================] - 869s 6s/step - loss: 0.4622 - accuracy: 0.8053 - val_loss: 0.2375 - val_accuracy: 0.9067 - lr: 0.0010
# Epoch 5/30
# 134/134 [==============================] - 882s 7s/step - loss: 0.4482 - accuracy: 0.8153 - val_loss: 0.2362 - val_accuracy: 0.9123 - lr: 0.0010
# Epoch 6/30
# 134/134 [==============================] - 771s 6s/step - loss: 0.4216 - accuracy: 0.8213 - val_loss: 0.2155 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 7/30
# 134/134 [==============================] - 663s 5s/step - loss: 0.3892 - accuracy: 0.8334 - val_loss: 0.2664 - val_accuracy: 0.9025 - lr: 0.0010
# Epoch 8/30
# 134/134 [==============================] - 732s 5s/step - loss: 0.3845 - accuracy: 0.8401 - val_loss: 0.2064 - val_accuracy: 0.9206 - lr: 0.0010
# Epoch 9/30
# 134/134 [==============================] - 750s 6s/step - loss: 0.3767 - accuracy: 0.8397 - val_loss: 0.1934 - val_accuracy: 0.9318 - lr: 0.0010
# Epoch 10/30
# 134/134 [==============================] - 750s 6s/step - loss: 0.3741 - accuracy: 0.8376 - val_loss: 0.2179 - val_accuracy: 0.9109 - lr: 0.0010
# Epoch 11/30
# 134/134 [==============================] - 745s 6s/step - loss: 0.3474 - accuracy: 0.8529 - val_loss: 0.2069 - val_accuracy: 0.9234 - lr: 0.0010
# Epoch 12/30
# 134/134 [==============================] - 743s 6s/step - loss: 0.3526 - accuracy: 0.8471 - val_loss: 0.2181 - val_accuracy: 0.9192 - lr: 0.0010
# Epoch 13/30
# 134/134 [==============================] - 751s 6s/step - loss: 0.3420 - accuracy: 0.8534 - val_loss: 0.1892 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 14/30
# 134/134 [==============================] - 751s 6s/step - loss: 0.3524 - accuracy: 0.8453 - val_loss: 0.2053 - val_accuracy: 0.9234 - lr: 0.0010
# Epoch 15/30
# 134/134 [==============================] - 752s 6s/step - loss: 0.3438 - accuracy: 0.8522 - val_loss: 0.2320 - val_accuracy: 0.9206 - lr: 0.0010
# Epoch 16/30
# 134/134 [==============================] - 747s 6s/step - loss: 0.3310 - accuracy: 0.8541 - val_loss: 0.1959 - val_accuracy: 0.9248 - lr: 0.0010
# Epoch 17/30
# 134/134 [==============================] - 745s 6s/step - loss: 0.3275 - accuracy: 0.8578 - val_loss: 0.2167 - val_accuracy: 0.9136 - lr: 0.0010
# Epoch 18/30
# 134/134 [==============================] - 746s 6s/step - loss: 0.3197 - accuracy: 0.8613 - val_loss: 0.2162 - val_accuracy: 0.9192 - lr: 0.0010

# %%
# Plot Crossentropy and Accuracy by epoch
functions.evaluation_plots(h_efv2s, 'Brain tumor with Augmentation')

# %%
# Validating set Plot Confusion Matrix and print Accuracy
functions.acc_conf_matrix(model, X=X_val, y=y_val, class_names_list = ['Glioma', 'Meningioma', 'No Tumor', 'Pituitary'])
# Out:
# Accuracy_score: 0.929

# %%
# Testing set Plot Confusion Matrix and print Accuracy
functions.acc_conf_matrix(model, X=X_test, y=y_test, class_names_list = ['Glioma', 'Meningioma', 'No Tumor', 'Pituitary'])
# Out:
# Accuracy_score: 0.769

# %%
model = Sequential()

model.add(effnet)
model.add(GlobalAveragePooling2D())
model.add(Dropout(.2))

#Just use a single output layer
model.add(Dense(4, activation='softmax'))

# Compile
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

h_efv2s = model.fit(X_train, y_train, validation_data = (X_val, y_val), steps_per_epoch=len(X_train) / 32, epochs=30, callbacks = [es, reduce_lr])
# Out:
# Epoch 1/30
# 134/134 [==============================] - 275s 2s/step - loss: 0.7829 - accuracy: 0.6540 - val_loss: 0.3765 - val_accuracy: 0.8524 - lr: 0.0010
# Epoch 2/30
# 134/134 [==============================] - 261s 2s/step - loss: 0.6232 - accuracy: 0.7212 - val_loss: 0.3245 - val_accuracy: 0.8788 - lr: 0.0010
# Epoch 3/30
# 134/134 [==============================] - 257s 2s/step - loss: 0.5600 - accuracy: 0.7558 - val_loss: 0.3041 - val_accuracy: 0.8816 - lr: 0.0010
# Epoch 4/30
# 134/134 [==============================] - 263s 2s/step - loss: 0.5319 - accuracy: 0.7609 - val_loss: 0.3288 - val_accuracy: 0.8705 - lr: 0.0010
# Epoch 5/30
# 134/134 [==============================] - 264s 2s/step - loss: 0.4974 - accuracy: 0.7688 - val_loss: 0.2646 - val_accuracy: 0.8900 - lr: 0.0010
# Epoch 6/30
# 134/134 [==============================] - 258s 2s/step - loss: 0.4762 - accuracy: 0.7874 - val_loss: 0.3063 - val_accuracy: 0.8886 - lr: 0.0010
# Epoch 7/30
# 134/134 [==============================] - 258s 2s/step - loss: 0.4604 - accuracy: 0.7925 - val_loss: 0.2786 - val_accuracy: 0.8900 - lr: 0.0010
# Epoch 8/30
# 134/134 [==============================] - 260s 2s/step - loss: 0.4597 - accuracy: 0.7962 - val_loss: 0.2165 - val_accuracy: 0.9178 - lr: 0.0010
# Epoch 9/30
# 134/134 [==============================] - 264s 2s/step - loss: 0.4351 - accuracy: 0.8083 - val_loss: 0.2215 - val_accuracy: 0.9109 - lr: 0.0010
# Epoch 10/30
# 134/134 [==============================] - 265s 2s/step - loss: 0.4194 - accuracy: 0.8164 - val_loss: 0.2285 - val_accuracy: 0.9206 - lr: 0.0010
# Epoch 11/30
# 134/134 [==============================] - 265s 2s/step - loss: 0.4169 - accuracy: 0.8155 - val_loss: 0.2089 - val_accuracy: 0.9206 - lr: 0.0010
# Epoch 12/30
# 134/134 [==============================] - 260s 2s/step - loss: 0.4114 - accuracy: 0.8132 - val_loss: 0.2100 - val_accuracy: 0.9136 - lr: 0.0010
# Epoch 13/30
# 134/134 [==============================] - 257s 2s/step - loss: 0.4025 - accuracy: 0.8176 - val_loss: 0.3570 - val_accuracy: 0.8802 - lr: 0.0010
# Epoch 14/30
# 134/134 [==============================] - 259s 2s/step - loss: 0.3987 - accuracy: 0.8211 - val_loss: 0.2049 - val_accuracy: 0.9234 - lr: 0.0010
# Epoch 15/30
# 134/134 [==============================] - 262s 2s/step - loss: 0.3960 - accuracy: 0.8241 - val_loss: 0.2080 - val_accuracy: 0.9192 - lr: 0.0010
# Epoch 16/30
# 134/134 [==============================] - 262s 2s/step - loss: 0.3880 - accuracy: 0.8304 - val_loss: 0.2086 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 17/30
# 134/134 [==============================] - 263s 2s/step - loss: 0.3740 - accuracy: 0.8306 - val_loss: 0.1978 - val_accuracy: 0.9220 - lr: 0.0010
# Epoch 18/30
# 134/134 [==============================] - 260s 2s/step - loss: 0.3769 - accuracy: 0.8371 - val_loss: 0.2126 - val_accuracy: 0.9136 - lr: 0.0010
# Epoch 19/30
# 134/134 [==============================] - 261s 2s/step - loss: 0.3759 - accuracy: 0.8313 - val_loss: 0.2257 - val_accuracy: 0.9150 - lr: 0.0010
# Epoch 20/30
# 134/134 [==============================] - 260s 2s/step - loss: 0.3668 - accuracy: 0.8353 - val_loss: 0.2065 - val_accuracy: 0.9234 - lr: 0.0010
# Epoch 21/30
# 134/134 [==============================] - 260s 2s/step - loss: 0.3697 - accuracy: 0.8418 - val_loss: 0.2069 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 22/30
# 134/134 [==============================] - 261s 2s/step - loss: 0.3665 - accuracy: 0.8367 - val_loss: 0.1872 - val_accuracy: 0.9276 - lr: 0.0010
# Epoch 23/30
# 134/134 [==============================] - 262s 2s/step - loss: 0.3547 - accuracy: 0.8388 - val_loss: 0.2685 - val_accuracy: 0.9053 - lr: 0.0010
# Epoch 24/30
# 134/134 [==============================] - 262s 2s/step - loss: 0.3496 - accuracy: 0.8432 - val_loss: 0.2039 - val_accuracy: 0.9331 - lr: 0.0010
# Epoch 25/30
# 134/134 [==============================] - 264s 2s/step - loss: 0.3537 - accuracy: 0.8408 - val_loss: 0.1847 - val_accuracy: 0.9290 - lr: 0.0010
# Epoch 26/30
# 134/134 [==============================] - 260s 2s/step - loss: 0.3528 - accuracy: 0.8408 - val_loss: 0.2278 - val_accuracy: 0.9234 - lr: 0.0010
# Epoch 27/30
# 134/134 [==============================] - 254s 2s/step - loss: 0.3515 - accuracy: 0.8483 - val_loss: 0.1774 - val_accuracy: 0.9429 - lr: 0.0010
# Epoch 28/30
# 134/134 [==============================] - 253s 2s/step - loss: 0.3462 - accuracy: 0.8499 - val_loss: 0.1803 - val_accuracy: 0.9304 - lr: 0.0010
# Epoch 29/30
# 134/134 [==============================] - 255s 2s/step - loss: 0.3440 - accuracy: 0.8520 - val_loss: 0.1763 - val_accuracy: 0.9401 - lr: 0.0010
# Epoch 30/30
# 134/134 [==============================] - 261s 2s/step - loss: 0.3504 - accuracy: 0.8439 - val_loss: 0.1914 - val_accuracy: 0.9359 - lr: 0.0010

# %%
# Plot Crossentropy and Accuracy by epoch
functions.evaluation_plots(h_efv2s, 'Brain tumor with Augmentation')

# %%
# Validating set Plot Confusion Matrix and print Accuracy
functions.acc_conf_matrix(model, X=X_val, y=y_val, class_names_list = ['Glioma', 'Meningioma', 'No Tumor', 'Pituitary'])
# Out:
# Accuracy_score: 0.9359

# %%
# Testing set Plot Confusion Matrix and print Accuracy
functions.acc_conf_matrix(model, X=X_test, y=y_test, class_names_list = ['Glioma', 'Meningioma', 'No Tumor', 'Pituitary'])
# Out:
# Accuracy_score: 0.7538

# %% [markdown]
# ---

# %% [markdown]
# I have tried ImageDataGenerator and Albumentations neither of them imroved the scores of the models.
